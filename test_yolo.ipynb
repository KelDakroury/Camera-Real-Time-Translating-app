# %% [markdown]
# #Installing ImageAI

# %% [markdown]
# Downgrading TensorFlow

# %%
# !pip install tensorflow==1.14.0
# !pip install keras==2.2.0
# !pip install 'h5py==2.10.0' --force-reinstall
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/1.0/yolo.h5
# !pip3 install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.14.0

# %% [markdown]
# #Instantiate YOLO

# %% [markdown]
# **ImageAI Documentation**
# [Detection Classes](https://imageai.readthedocs.io/en/latest/detection/)

# %%
# !pip install 'h5py==2.10.0' --force-reinstall
import warnings
warnings.filterwarnings('ignore')

# %%
from imageai.Detection import ObjectDetection

import os
import time

exec_path = os.getcwd()
yolo_obj = ObjectDetection()
yolo_obj.setModelTypeAsYOLOv3()
yolo_obj.setModelPath( os.path.join(exec_path , "yolo.h5"))
yolo_obj.loadModel()

# %% [markdown]
# #Reading image

# %%
pip install --upgrade jupyter_http_over_ws>=0.0.7 && jupyter serverextension enable --py jupyter_http_over_ws
# Out:
# Enabling: jupyter_http_over_ws
# - Writing config: /root/.jupyter
#     - Validating...
#       jupyter_http_over_ws 0.0.7 OK

# %%
from PIL import Image

# %%
Image.open("image1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F5260B167D0>

# %% [markdown]
# #Detecting object in the image

# %%
start = time.time()
detections = yolo_obj.detectObjectsFromImage(input_image=os.path.join(exec_path , "/content/10best-cars-group-cropped-1542126037.jpg"), output_image_path=os.path.join(exec_path , "out_img1.jpg"))
print('Time Taken (in seconds)',time.time() - start)
for eachObject in detections:
    print(eachObject["name"] , " : " , eachObject["percentage_probability"] )
Image.open("out_img1.jpg")
# Out:
# Time Taken (in seconds) 7.007625102996826
# car  :  97.63630032539368
# car  :  98.63101243972778
# car  :  98.98608922958374
# car  :  99.10041689872742
# car  :  99.31029081344604
# car  :  99.51448440551758
# car  :  99.5364785194397
# car  :  99.60334897041321
# car  :  99.63434338569641
# car  :  99.68024492263794
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F5260B16690>
